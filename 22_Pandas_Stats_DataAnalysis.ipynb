# %% [markdown]
# <a href="https://colab.research.google.com/github/Uzma-Jawed/python-class_work-and-practice/blob/main/22_Pandas_Stats_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# @UzmaJawed
#
#
# ---
# "BEhind every great data scientist is a trail of cleaned datasets and conquered outliers!"
#
#
# ---

# %% [markdown]
# 📊 Exploratory Data Analysis (EDA) with California Housing Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Data Loading & Initial Inspection
#
# 🔍 Understanding the Dataset
#
# We begin by loading and examining our California housing dataset to understand its structure and contents.

# %%
# Load dataset
data = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
# Display first 5 rows
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Display last 5 rows
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
# Check dataset dimensions
print(f"Dataset contains {data.shape[0]} rows and {data.shape[1]} columns")
# Out:
# Dataset contains 17000 rows and 9 columns

# %%
# Show column information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# Generate summary statistics
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ---
#
#
# Key Observations:
#
# The dataset contains 17,000 entries (rows) with 9 features (columns)
#
# All columns contain numerical data (no missing values shown)
#
# Statistics show mean, standard deviation, and quartile values for each feature
#
#
# ---

# %% [markdown]
# 2. Statistical Analysis Foundations
#
# 📌 Measures of Central Tendency
#
# These help us understand where most values in a distribution fall.
#
#
# ---

# %%
# Mean (Average value)
print("Mean values:")
print(data.mean())
# Out:
# Mean values:
# longitude               -119.562108
# latitude                  35.625225
# housing_median_age        28.589353
# total_rooms             2643.664412
# total_bedrooms           539.410824
# population              1429.573941
# households               501.221941
# median_income              3.883578
# median_house_value    207300.912353
# dtype: float64

# %%
# Median (Middle value)
print("\nMedian values:")
print(data.median())
# Out:
# Median values:
# longitude               -118.4900
# latitude                  34.2500
# housing_median_age        29.0000
# total_rooms             2127.0000
# total_bedrooms           434.0000
# population              1167.0000
# households               409.0000
# median_income              3.5446
# median_house_value    180400.0000
# dtype: float64

# %%
# Mode (Most frequent value)
print("\nMode values:")
print(data.mode().iloc[0])  # Showing first mode if multiple exist
# Out:
# Mode values:
# longitude               -118.310
# latitude                  34.060
# housing_median_age        52.000
# total_rooms             1582.000
# total_bedrooms           280.000
# population               891.000
# households               306.000
# median_income              3.125
# median_house_value    500001.000
# Name: 0, dtype: float64

# %% [markdown]
# ---
#
#
# Explanation:
#
# Mean: Sensitive to outliers, good for normally distributed data
#
# Median: Robust to outliers, better for skewed distributions
#
# Mode: Useful for identifying most common values
#
#
# ---

# %% [markdown]
# ---
#
#
# 📏 Measures of Dispersion
#
# These quantify how spread out our data is.
#
#
# ---

# %%
# Range (Max - Min)
print("Ranges for each column:")
print(data.max() - data.min())
# Out:
# Ranges for each column:
# longitude                 10.0400
# latitude                   9.4100
# housing_median_age        51.0000
# total_rooms            37935.0000
# total_bedrooms          6444.0000
# population             35679.0000
# households              6081.0000
# median_income             14.5002
# median_house_value    485002.0000
# dtype: float64

# %%
# Variance
print("\nVariance:")
print(data.var())
# Out:
# Variance:
# longitude             4.020692e+00
# latitude              4.568221e+00
# housing_median_age    1.584310e+02
# total_rooms           4.752169e+06
# total_bedrooms        1.776618e+05
# population            1.317566e+06
# households            1.478563e+05
# median_income         3.641061e+00
# median_house_value    1.345223e+10
# dtype: float64

# %%
# Standard Deviation
print("\nStandard Deviation:")
print(data.std())
# Out:
# Standard Deviation:
# longitude                  2.005166
# latitude                   2.137340
# housing_median_age        12.586937
# total_rooms             2179.947071
# total_bedrooms           421.499452
# population              1147.852959
# households               384.520841
# median_income              1.908157
# median_house_value    115983.764387
# dtype: float64

# %% [markdown]
# ---
#
#
# ### 📊 Key Statistical Measures
#
# | Measure      | Description                      | When to Use                 |
# |--------------|----------------------------------|-----------------------------|
# | **Range**    | Simplest measure of spread       | Quick overview of data span  |
# | **Variance** | Average squared deviations       | Theoretical calculations    |
# | **Std Dev**  | Square root of variance          | Practical data interpretation|
# | **IQR**      | Range of middle 50% of data      | Robust outlier detection    |
# | **QD**       | (Q3-Q1)/2                       | Measuring quartile spread   |
#
#
# ---

# %% [markdown]
# 3. Quartile Analysis & Outlier Detection
#
# 📊 Understanding Quartiles
#
# Quartiles divide our data into four equal parts.
#
#
# ---

# %%
# Calculate quartiles for age column
age_q1 = data['housing_median_age'].quantile(0.25)
age_q3 = data['housing_median_age'].quantile(0.75)
age_iqr = age_q3 - age_q1

print(f"Age Quartiles: Q1 = {age_q1}, Q3 = {age_q3}")
print(f"IQR: {age_iqr}")
# Out:
# Age Quartiles: Q1 = 18.0, Q3 = 37.0
# IQR: 19.0

# %% [markdown]
# ---
# 🔍 Quartile Deviation Metrics
#
# These help us understand the spread of the middle 50% of our data.
#
#
# ---

# %%
# Quartile Deviation (QD)
qd = age_iqr / 2
print(f"Quartile Deviation: {qd}")
# Out:
# Quartile Deviation: 9.5

# %%
# Coefficient of QD
coeff_qd = (age_q3 - age_q1) / (age_q3 + age_q1)
print(f"Coefficient of QD: {coeff_qd:.4f}")
# Out:
# Coefficient of QD: 0.3455

# %% [markdown]
# ---
#
# Interpretation:
#
# A higher coefficient indicates greater dispersion
#
# Values range from 0 to 1 (0 = no dispersion, 1 = maximum dispersion)
#
#
# ---

# %% [markdown]
# ---
#
#
# 4. Comprehensive Outlier Analysis
#
# 🚨 IQR Outlier Detection Method
#
# We'll use the robust IQR method to identify unusual values in the 'households' column.
#
#
# ---

# %%
column = 'households'

# %%
# Calculate range
col_range = data[column].max() - data[column].min()
print(f"Range of {column}: {col_range}")
# Out:
# Range of households: 6081.0

# %%
# Calculate quartiles
q1 = data[column].quantile(0.25)
q3 = data[column].quantile(0.75)
iqr = q3 - q1
print(f"\nQuartiles: Q1 = {q1}, Q3 = {q3}")
# Out:
# Quartiles: Q1 = 282.0, Q3 = 605.25

# %%
print(f"IQR: {iqr}")
# Out:
# IQR: 323.25

# %%
# Determine outlier boundaries
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
print(f"\nOutlier Thresholds:")
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Outlier Thresholds:
# Lower bound: -202.875
# Upper bound: 1090.125

# %%
# Identify outliers
outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
print(f"\nFound {len(outliers)} outliers ({len(outliers)/len(data)*100:.2f}% of data)")
# Out:
# Found 1032 outliers (6.07% of data)

# %%
# Display outliers
outliers.head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 133    -116.06     34.15                15.0      10377.0          2331.0
# 135    -116.09     34.15                13.0       9444.0          1997.0
# 164    -116.23     33.72                32.0       4981.0          1326.0
# 165    -116.23     33.71                17.0       4874.0          1349.0
# 168    -116.24     33.71                10.0       9033.0          2224.0
#
#      population  households  median_income  median_house_value
# 133      4507.0      1807.0         2.2466             66800.0
# 135      4166.0      1482.0         2.6111             65600.0
# 164      3779.0      1186.0         1.7805             76900.0
# 165      5032.0      1243.0         2.4440             90000.0
# 168      5525.0      1845.0         2.7598             95000.0

# %% [markdown]
# ---
#
# ### Outlier Analysis Insights:
#
# The IQR method identifies values outside 1.5×IQR from the quartiles
#
# **Outliers may represent:**
#
# Data entry errors
#
# Genuine extreme cases
#
# Measurement anomalies
#
# **Decisions needed on whether to:**
#
# Remove outliers
#
# Transform values
#
# Keep them if meaningful
#
#
# ---

# %% [markdown]
# 5. Visual Confirmation
#
# 📊 Boxplot Visualization
#
# Visualizing helps validate our numerical findings.
#
#
# ---

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=data['households'])
plt.title('Distribution of Households with Outliers Marked', pad=20)
plt.xlabel('Number of Households')
plt.show()

# %% [markdown]
# ### Boxplot Components:
#
# The box shows IQR (middle 50% of data)
#
# Whiskers extend to 1.5×IQR
#
# Points beyond whiskers are considered outliers
#
# Median line shows central tendency
#
#
# ---

# %% [markdown]
# ### 📝 Summary & Next Steps
# Key Takeaways
#
# **Central Tendency:** Understand where most values cluster
#
# **Dispersion:** Quantify how spread out values are
#
# **Quartiles:** Analyze data distribution segments
#
# **Outliers:** Identify and handle extreme values

# %% [markdown]
# ---
#
# ### Recommended Next Steps
#
# 1.Outlier Investigation:

# %%
# Example: Examine outlier characteristics
outliers.describe()
# Out:
#          longitude     latitude  housing_median_age   total_rooms  \
# count  1032.000000  1032.000000         1032.000000   1032.000000
# mean   -119.221841    35.282316           17.381783   8454.437016
# std       1.962469     1.970485            9.540235   4237.591513
# min    -122.790000    32.550000            2.000000   2124.000000
# 25%    -121.530000    33.910000           10.000000   5815.750000
# 50%    -118.380000    34.160000           17.000000   7251.500000
# 75%    -117.747500    37.512500           23.000000   9777.750000
# max    -116.060000    41.610000           52.000000  37937.000000
#
#        total_bedrooms    population   households  median_income  \
# count     1032.000000   1032.000000  1032.000000    1032.000000
# mean      1744.440891   4366.825581  1609.804264       4.008096
# std        674.838970   2280.761974   612.869303       1.679436
# min       1078.000000   1525.000000  1091.000000       0.677500
# ...

# %% [markdown]
# ---
#
# 2. Data Transformation (if needed):
#
#
# ---

# %%
# Log transformation example
import numpy as np
data['households_log'] = np.log(data['households'] + 1)

# %% [markdown]
# ---
#
# 3. Expand Analysis:
#
#
# ---

# %%
# Apply similar analysis to other columns
numeric_cols = data.select_dtypes(include='number').columns
for col in numeric_cols:
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    print(f"\n{col} IQR: {q3 - q1}")
# Out:
# longitude IQR: 3.7900000000000063
#
# latitude IQR: 3.789999999999999
#
# housing_median_age IQR: 19.0
#
# total_rooms IQR: 1689.25
#
# total_bedrooms IQR: 351.25
#
# population IQR: 931.0
#
# households IQR: 323.25
#
# median_income IQR: 2.2006250000000005
#
# median_house_value IQR: 145600.0
#
# households_log IQR: 0.761845289673623
