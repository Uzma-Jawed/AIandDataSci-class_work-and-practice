# %% [markdown]
# <a href="https://colab.research.google.com/github/Uzma-Jawed/python-class_work-and-practice/blob/main/24_DataAnalysis%26Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📘 Uzma Jawed
#
# 📅 Class Work - August 02

# %%
import pandas as pd

# %%
data = {
    "Marks": [70, 85, 60, 90, 75]
}

df = pd.DataFrame(data)

# calculate variance
variance = df["Marks"].var()

print("variance:", variance)
# Out:
# variance: 142.5

# %%
df.corr()
# Out:
#        Marks
# Marks    1.0

# %%
df.cov()
# Out:
#        Marks
# Marks  142.5

# %%
# Load dataset
data = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
# Display entire dataframe (optional: usually shows full data in Colab)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
data.cov()
# Out:
#                        longitude      latitude  housing_median_age  \
# longitude               4.020692     -3.965185           -2.883552
# latitude               -3.965185      4.568221            0.442652
# housing_median_age     -2.883552      0.442652          158.430983
# total_rooms           205.489998   -180.652575        -9904.992690
# total_bedrooms         60.685329    -62.497196        -1700.026828
# population            234.017167   -272.963262        -4275.001960
# households             45.974646    -61.558579        -1465.311997
# median_income          -0.059248     -0.327506           -2.784428
# median_house_value -10461.246889 -35924.378200       155853.476977
#
#                      total_rooms  total_bedrooms    population    households  \
# longitude           2.054900e+02    6.068533e+01  2.340172e+02  4.597465e+01
# latitude           -1.806526e+02   -6.249720e+01 -2.729633e+02 -6.155858e+01
# ...

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %%
import seaborn as sns

# %%
# 📌 Visualizing Correlation Matrix using Seaborn

import seaborn as sns
import matplotlib.pyplot as plt

# Basic heatmap
sns.heatmap(data.corr())
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Heatmap with values and color theme
sns.heatmap(data.corr(), annot=True, cmap='Blues')
plt.title("Correlation Heatmap - Blues")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - Blues')

# %%
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap - Coolwarm")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - Coolwarm')

# %%
sns.heatmap(data.corr(), annot=True, cmap='viridis')
plt.title("Correlation Heatmap - Viridis")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap - Viridis')

# %%
# 📌 GroupBy and Aggregation

# Average house value for each age group
data.groupby("housing_median_age")['median_house_value'].mean().head()
# Out:
# housing_median_age
# 1.0    190250.000000
# 2.0    229438.836735
# 3.0    239450.043478
# 4.0    230054.105590
# 5.0    211035.708543
# Name: median_house_value, dtype: float64

# %%
data.groupby("housing_median_age")['median_house_value'].mean()
# Out:
# housing_median_age
# 1.0     190250.000000
# 2.0     229438.836735
# 3.0     239450.043478
# 4.0     230054.105590
# 5.0     211035.708543
# 6.0     206768.240310
# 7.0     188445.059603
# 8.0     190805.073034
# 9.0     190306.994186
# 10.0    178416.393805
# 11.0    182480.312500
# 12.0    181590.640625
# 13.0    188065.473896
# 14.0    191181.288184
# 15.0    181031.024038
# 16.0    200354.507087
# 17.0    191772.244792
# 18.0    192074.715481
# 19.0    196017.752427
# 20.0    192681.751958
# 21.0    200918.536193
# 22.0    213129.173375
# 23.0    204621.787958
# 24.0    207293.365039
# 25.0    223097.223427
# 26.0    206773.793241
# 27.0    206728.259446
# 28.0    210049.812500
# 29.0    195185.863636
# 30.0    201559.145833
# 31.0    208319.851562
# 32.0    207131.500000
# 33.0    203922.269006
# 34.0    213061.615520
# 35.0    205624.462428
# 36.0    208262.422378
# 37.0    209008.299771
# 38.0    195272.371069
# 39.0    206718.913907
# 40.0    205783.594378
# ...

# %%
# Full summary of each age group
data.groupby("housing_median_age").mean().head()
# Out:
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -121.465000  37.940000  2158.000000      335.500000
# 2.0                -119.035306  35.410816  5237.102041      871.448980
# 3.0                -118.798478  35.164783  6920.326087     1190.826087
# 4.0                -118.805093  34.987764  6065.614907     1068.192547
# 5.0                -118.789497  35.095327  4926.261307      910.924623
#
#                      population   households  median_income  \
# housing_median_age
# 1.0                  637.000000   190.000000       4.756800
# 2.0                 2005.224490   707.122449       5.074237
# 3.0                 2934.673913  1030.413043       5.572013
# 4.0                 2739.956522   964.291925       5.196055
# 5.0                 2456.979899   826.768844       4.732460
#
#                     median_house_value
# housing_median_age
# 1.0                      190250.000000
# ...

# %%
# Mean and Median of house values grouped by age
data.groupby('housing_median_age')['median_house_value'].agg(['mean', 'median']).head()
# Out:
#                              mean    median
# housing_median_age
# 1.0                 190250.000000  190250.0
# 2.0                 229438.836735  191700.0
# 3.0                 239450.043478  216400.0
# 4.0                 230054.105590  198900.0
# 5.0                 211035.708543  176900.0

# %%
# Aggregating multiple functions on multiple columns
data.aggregate({
    'housing_median_age': ['mean', 'sum'],
    'median_house_value': ['mean', 'max']
})
# Out:
#       housing_median_age  median_house_value
# mean           28.589353       207300.912353
# sum        486019.000000                 NaN
# max                  NaN       500001.000000

# %%
# calculate mean etc using groupby of 3 columns

# %%
# GroupBy with 3 Columns and Mean
grouped_mean = data.groupby(['housing_median_age', 'total_rooms', 'total_bedrooms'])['median_house_value'].mean()
grouped_mean.head()
# Out:
# housing_median_age  total_rooms  total_bedrooms
# 1.0                 2062.0       343.0             191300.0
#                     2254.0       328.0             189200.0
# 2.0                 96.0         18.0               47500.0
#                     227.0        35.0              434700.0
#                     337.0        55.0              164800.0
# Name: median_house_value, dtype: float64

# %%
# GroupBy with Aggregate Functions

# %%
grouped_stats = data.groupby(['housing_median_age', 'total_rooms', 'total_bedrooms'])['median_house_value'].agg(['mean', 'max', 'min', 'count'])
grouped_stats.head()
# Out:
#                                                    mean       max       min  \
# housing_median_age total_rooms total_bedrooms
# 1.0                2062.0      343.0           191300.0  191300.0  191300.0
#                    2254.0      328.0           189200.0  189200.0  189200.0
# 2.0                96.0        18.0             47500.0   47500.0   47500.0
#                    227.0       35.0            434700.0  434700.0  434700.0
#                    337.0       55.0            164800.0  164800.0  164800.0
#
#                                                count
# housing_median_age total_rooms total_bedrooms
# 1.0                2062.0      343.0               1
#                    2254.0      328.0               1
# 2.0                96.0        18.0                1
#                    227.0       35.0                1
#                    337.0       55.0                1

# %%
# Reset Index to Flatten

# %%
grouped_stats.reset_index().head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms      mean       max  \
# 0                 1.0       2062.0           343.0  191300.0  191300.0
# 1                 1.0       2254.0           328.0  189200.0  189200.0
# 2                 2.0         96.0            18.0   47500.0   47500.0
# 3                 2.0        227.0            35.0  434700.0  434700.0
# 4                 2.0        337.0            55.0  164800.0  164800.0
#
#         min  count
# 0  191300.0      1
# 1  189200.0      1
# 2   47500.0      1
# 3  434700.0      1
# 4  164800.0      1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/housing-prices-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/housing-prices-dataset

# %%
# load dataset

import pandas as pd

house_data = pd.read_csv("/content/Housing.csv")

# %%
# Display the dataset
house_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Describe the dataset
house_data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
house_data.describe(include='all')
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  545.000000  545.000000  545.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std     1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %%
house_data.describe(include=[object])
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
house_data.value_counts()

# %%
# Use value_counts() on a specific column
house_data['airconditioning'].value_counts()
# Out:
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64

# %%
house_data['furnishingstatus'].unique()  # This returns the unique values in that column
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
house_data['furnishingstatus'].nunique()  # Returns number of unique values
# Out:
# 3

# %% [markdown]
# ## 🟩 Variance:
# A measure of how much the data points differ from the mean.
#
# ## 🟦 Covariance:
# Shows how two variables change together.
# - Positive → both increase together
# - Negative → one increases, the other decreases
#
# ## 🟨 Correlation:
# Normalized form of covariance, ranges from -1 to 1.
# - +1 → strong positive relationship
# - -1 → strong negative relationship
# - 0 → no relationship
#
# ## 🟪 groupby():
# Used to group rows based on a column and apply summary stats like mean, count, etc.
#
# ## 🟥 aggregate():
# Used to apply multiple functions at once to grouped or entire data, useful in multi-metric analysis.
